# %%
from pathlib import Path

ROOT = Path(globals()['__vsc_ipynb_file__']).parent.parent
print(ROOT)

import sys
sys.path.append(str(ROOT))
# Out:
# /Users/gabrieleagliardi/Documents/GitHub/Client-Vanguard-Optimization

# %%
from src.experiment import Experiment
from src.plots import analyse_df_step4, analyse_df_step4_slide

# %%
df_all = Experiment.df_experiments(Experiment.read_experiments())

# %% [markdown]
# # Simulator, 31 qubits, no local search

# %% [markdown]
# ## TwoLocal, full entanglement

# %% [markdown]
# ### Varying alpha

# %%
df = Experiment.filter_experiments(df_all,
                                   ansatz='TwoLocal',
                                   ansatz_params_entanglement='full',
                                   device='AerSimulator',
                                   optimizer='nft',
                                   has_step4=True,
                                   )
analyse_df_step4(df, 'alpha', num_iters=20)
# Out:
# size: 50

# %% [markdown]
# ### Varying reps

# %%
df = Experiment.filter_experiments(df_all,
                                   ansatz='TwoLocal',
                                   ansatz_params_entanglement='full',
                                   device='AerSimulator',
                                   optimizer='nft',
                                   has_step4=True,
                                   )
analyse_df_step4(df, 'ansatz_params_reps', num_iters=20)
# Out:
# size: 50

# %% [markdown]
# ## TwoLocal, bilinear entanglement

# %% [markdown]
# ### Varying alpha

# %%
df = Experiment.filter_experiments(df_all,
                                   ansatz='TwoLocal',
                                   ansatz_params_entanglement='bilinear',
                                   device='AerSimulator',
                                   optimizer='nft',
                                   has_step4=True,
                                   )
analyse_df_step4(df, 'alpha', num_iters=20)
# Out:
# size: 90

# %% [markdown]
# ### Varying reps

# %%
df = Experiment.filter_experiments(df_all,
                                   ansatz='TwoLocal',
                                   ansatz_params_entanglement='bilinear',
                                   device='AerSimulator',
                                   optimizer='nft',
                                   has_step4=True,
                                   )
analyse_df_step4(df, 'ansatz_params_reps', num_iters=20)
# Out:
# size: 90

# %% [markdown]
# ### Focus alpha=.1

# %%
df = Experiment.filter_experiments(df_all,
                                   ansatz='TwoLocal',
                                   ansatz_params_entanglement='bilinear',
                                   device='AerSimulator',
                                   optimizer='nft',
                                   has_step4=True,
                                   alpha=.1
                                   )
analyse_df_step4(df, 'ansatz_params_reps', num_iters=20)
# Out:
# size: 30

# %% [markdown]
# ### Focus reps=2

# %%
df = Experiment.filter_experiments(df_all,
                                   ansatz='TwoLocal',
                                   ansatz_params_entanglement='bilinear',
                                   device='AerSimulator',
                                   optimizer='nft',
                                   has_step4=True,
                                   ansatz_params_reps=2
                                   )
analyse_df_step4(df, 'alpha', num_iters=20)
# Out:
# size: 30

# %% [markdown]
# ### Focus reps=1

# %%
df = Experiment.filter_experiments(df_all,
                                   ansatz='TwoLocal',
                                   ansatz_params_entanglement='bilinear',
                                   device='AerSimulator',
                                   optimizer='nft',
                                   has_step4=True,
                                   ansatz_params_reps=1
                                   )
analyse_df_step4(df, 'alpha', num_iters=20)
# Out:
# size: 30

# %% [markdown]
# # Slide plots

# %%
df = Experiment.filter_experiments(df_all,
                                   ansatz='TwoLocal',
                                   ansatz_params_entanglement='full',
                                   device='AerSimulator',
                                   optimizer='nft',
                                   has_step4=True,
                                   )
analyse_df_step4_slide(df, 'alpha', num_iters=20)
analyse_df_step4_slide(df, 'ansatz_params_reps', num_iters=20)
df = Experiment.filter_experiments(df_all,
                                   ansatz='TwoLocal',
                                   ansatz_params_entanglement='bilinear',
                                   device='AerSimulator',
                                   optimizer='nft',
                                   has_step4=True,
                                   )
analyse_df_step4_slide(df, 'alpha', num_iters=20)
analyse_df_step4_slide(df, 'ansatz_params_reps', num_iters=20)
# Out:
# size: 50
# size: 50
# size: 90
# size: 90
